# %%
import requests
from tqdm.auto import tqdm

# %%
offset_ = 1 # размер шага
limit_ = 100 # количество объектов в одном ответе api
url = f'https://xn--80az8a.xn--d1aqf.xn--p1ai/%D1%81%D0%B5%D1%80%D0%B2%D0%B8%D1%81%D1%8B/api/kn/object?offset={offset_}&limit={limit_}&sortField=devId.devShortCleanNm&sortType=asc&objStatus=0'
res = requests.get(url)
objects_data = res.json()
objects_data.get('data').get('list')[0]
# Out:
# {'buildType': 'Жилое',
#  'developer': {'companyGroup': 5776,
#   'devId': 306,
#   'devInn': '7701651356',
#   'fullName': '2МЕН ГРУПП',
#   'groupName': '2МЕН ГРУПП ДЕВЕЛОПМЕНТ',
#   'orgForm': {'fullForm': 'Акционерное общество', 'id': 1, 'shortForm': 'АО'},
#   'shortName': '2МЕН ГРУПП'},
#  'hobjId': 39024,
#  'hobjRenderPhotoUrl': 'https://xn--80az8a.xn--d1aqf.xn--p1ai/api/ext/file/6C6B7A3A7DA9AAFAA1F245B09666D97D31445BA1',
#  'latitude': 57.1519,
#  'longitude': 65.5536,
#  'objAddr': 'г Тюмень, ул Профсоюзная, д. 56',
#  'objCompensFundFlg': 1,
#  'objElemLivingCnt': 68,
#  'objFloorMax': 20,
#  'objFloorMin': 4,
#  'objGuarantyEscrowFlg': 0,
#  'objId': 13383,
#  'objPriceAVG': 66773,
#  'objProblemFlg': 0,
#  'objPublDt': '2019-05-31',
#  'objReady100PercDt': '2023-12-31',
#  'objSquareLiving': 6423.85,
#  'objStatus': 0,
#  'pdId': 28105,
#  'problemFlag': 'NONE',
#  'residentialBuildings': 1,
#  'rpdNum': '72-000095',
#  'rpdRegionCd': 72,
#  'siteStatus': 'Строящиеся'}

# %%
objects_list = objects_data.get('data').get('list')
objids = [x.get('objId') for x in objects_list]
objids[:10]
# Out:
# [13383, 13397, 13398, 13391, 10891, 56006, 30292, 18709, 18708, 27803]

# %%
import pandas as pd

# %%
df = pd.json_normalize(objects_list)
df.head
# Out:
# <bound method NDFrame.head of     hobjId  objId  rpdRegionCd                             objAddr  \
# 0    39024  13383           72     г Тюмень, ул Профсоюзная, д. 56
# 1    37201  13397           72     г Тюмень, ул Профсоюзная, д. 56
# 2    37165  13398           72     г Тюмень, ул Профсоюзная, д. 56
# 3    37219  13391           72     г Тюмень, ул Профсоюзная, д. 56
# 4     6541  10891           35  г Вологда, ул Медуницинская, д. 11
# ..     ...    ...          ...                                 ...
# 95   44064  33226           77                   д Зверево, д. 132
# 96   44003  33165           77                    д Зверево, д. 71
# 97   44054  33216           77                   д Зверево, д. 122
# 98   44002  33164           77                    д Зверево, д. 70
# 99   44023  33185           77                    д Зверево, д. 91
#
#     objFloorMin  objFloorMax  objElemLivingCnt objReady100PercDt  \
# 0             4           20                68        2023-12-31
# ...

# %%
writer = pd.ExcelWriter(r'C:\Users\18255623\Downloads\Data Scientist\Task2-DF.xlsx', engine='xlsxwriter')

# Write dataframe to new sheet
df.to_excel(writer, sheet_name='AnotherSheet')
# Close the Pandas Excel writer and output the Excel file.
writer.save()

# %%
#Write dataframe to pickle
df.to_pickle('Task2-DF.pkl')
df
# Out:
#     hobjId  objId  rpdRegionCd                             objAddr  \
# 0    39024  13383           72     г Тюмень, ул Профсоюзная, д. 56
# 1    37201  13397           72     г Тюмень, ул Профсоюзная, д. 56
# 2    37165  13398           72     г Тюмень, ул Профсоюзная, д. 56
# 3    37219  13391           72     г Тюмень, ул Профсоюзная, д. 56
# 4     6541  10891           35  г Вологда, ул Медуницинская, д. 11
# ..     ...    ...          ...                                 ...
# 95   44064  33226           77                   д Зверево, д. 132
# 96   44003  33165           77                    д Зверево, д. 71
# 97   44054  33216           77                   д Зверево, д. 122
# 98   44002  33164           77                    д Зверево, д. 70
# 99   44023  33185           77                    д Зверево, д. 91
#
#     objFloorMin  objFloorMax  objElemLivingCnt objReady100PercDt  \
# 0             4           20                68        2023-12-31
# ...
