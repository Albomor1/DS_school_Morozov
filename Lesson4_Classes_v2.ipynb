# %%
import csv
import matplotlib.pyplot as plt

class CSVReader:
    def __init__(self, file_path):
        self.file_path = file_path

    def read_csv(self):
        with open(self.file_path, 'r') as csv_file:
            reader = csv.reader(csv_file, delimiter=';')
            x_values = []
            y_values = []
            for row in reader:
                x_values.append(row[0])
                y_values.append(row[1])
            return x_values, y_values

class CSVGraph:
    def __init__(self, x_values, y_values, title):
        self.x_values = x_values
        self.y_values = y_values
        self.title = title

    def plot_graph(self):
        plt.plot(self.x_values, self.y_values)
        plt.xlabel('X Axis')
        plt.ylabel('Y Axis')
        plt.title(self.title)
        plt.show()

# Создание экземпляра класса
csv_reader = CSVReader('E:/git_exercise/class_df.csv')
csv_graph = CSVGraph(csv_reader.read_csv()[0], csv_reader.read_csv()[1], 'Title of the Graph')

# Построение графика
csv_graph.plot_graph()

# %%
import pickle
import matplotlib.pyplot as plt
import pandas as pd

class PickleReader:
    def __init__(self, file_path):
        self.file_path = file_path

    def read_pickle(self):
        with open(self.file_path, 'rb') as pickle_file:
            data = pickle.load(pickle_file)
            return data

class PickleGraph:
    def __init__(self, df):
        self.df = df

    def plot_graph(self):
        #plt.plot(self.df['region'], self.df['objSquareLiving'])
        grouped = self.df.groupby('region')
        for name, group in grouped:
            plt.plot(group['region'], group['objSquareLiving'], label=name)
        plt.xlabel('region')
        plt.ylabel('objSquareLiving')
        plt.show()

# Создание экземпляра класса
pickle_reader = PickleReader('E:/git_exercise/df_nashdomrf.pkl')
df = pd.DataFrame(pickle_reader.read_pickle())
pickle_graph = PickleGraph(df)

# Построение графика
pickle_graph.plot_graph()

# %%
import pickle
import matplotlib.pyplot as plt
import pandas as pd

class PickleReader:
    def __init__(self, file_path):
        self.file_path = file_path

    def read_pickle(self):
        with open(self.file_path, 'rb') as pickle_file:
            data = pickle.load(pickle_file)
            return data

class PickleGraph:
    def __init__(self, df):
        self.df = df

    def plot_graph(self):
        #plt.plot(self.df['region'], self.df['objSquareLiving'])
        grouped = self.df.groupby('region')
        for name, group in grouped:
            plt.plot(group['region'], group['objSquareLiving'].sum(), label=name)
        plt.xlabel('X Axis')
        plt.ylabel('Y Axis')
        plt.title('Title of the Graph')
        plt.show()

# Создание экземпляра класса
pickle_reader = PickleReader('E:/git_exercise/df_nashdomrf.pkl')
df = pd.DataFrame(pickle_reader.read_pickle())
pickle_graph = PickleGraph(df)

# Построение графика
pickle_graph.plot_graph()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[4], line 34
#      31 pickle_graph = PickleGraph(df)
#      33 # Построение графика
# ---> 34 pickle_graph.plot_graph()
#
# Cell In[4], line 22, in PickleGraph.plot_graph(self)
#      20 grouped = self.df.groupby('region')
#      21 for name, group in grouped:
# ---> 22     plt.plot(group['region'], group['objSquareLiving'].sum(), label=name)
#      23 plt.xlabel('X Axis')
#      24 plt.ylabel('Y Axis')
#
# File E:\anaconda3\Lib\site-packages\matplotlib\pyplot.py:2812, in plot(scalex, scaley, data, *args, **kwargs)
#    2810 @_copy_docstring_and_deprecators(Axes.plot)
#    2811 def plot(*args, scalex=True, scaley=True, data=None, **kwargs):
# -> 2812     return gca().plot(
#    2813         *args, scalex=scalex, scaley=scaley,
#    2814         **({"data": data} if data is not None else {}), **kwargs)
#
# File E:\anaconda3\Lib\site-packages\matplotlib\axes\_axes.py:1688, in Axes.plot(self, scalex, scaley, data, *args, **kwargs)
#    1445 """
#    1446 Plot y versus x as lines and/or markers.
#    1447
#    (...)
#    1685 (``'green'``) or hex strings (``'#008000'``).
#    1686 """
#    1687 kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D)
# -> 1688 lines = [*self._get_lines(*args, data=data, **kwargs)]
#    1689 for line in lines:
#    1690     self.add_line(line)
#
# File E:\anaconda3\Lib\site-packages\matplotlib\axes\_base.py:311, in _process_plot_var_args.__call__(self, data, *args, **kwargs)
#     309     this += args[0],
#     310     args = args[1:]
# --> 311 yield from self._plot_args(
#     312     this, kwargs, ambiguous_fmt_datakey=ambiguous_fmt_datakey)
#
# File E:\anaconda3\Lib\site-packages\matplotlib\axes\_base.py:504, in _process_plot_var_args._plot_args(self, tup, kwargs, return_kwargs, ambiguous_fmt_datakey)
#     501     self.axes.yaxis.update_units(y)
#     503 if x.shape[0] != y.shape[0]:
# --> 504     raise ValueError(f"x and y must have same first dimension, but "
#     505                      f"have shapes {x.shape} and {y.shape}")
#     506 if x.ndim > 2 or y.ndim > 2:
#     507     raise ValueError(f"x and y can be no greater than 2D, but have "
#     508                      f"shapes {x.shape} and {y.shape}")
#
# ValueError: x and y must have same first dimension, but have shapes (62,) and (1,)
